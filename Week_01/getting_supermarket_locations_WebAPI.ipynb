# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3456, 267)
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225154  8.969868       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.diet:seafood tags.brand:website tags.recycling:low_energy_bulbs  \
# 0               NaN                NaN                             NaN
# 1               NaN                NaN                             NaN
# 2               NaN                NaN                             NaN
# 3               NaN                NaN                             NaN
# 4               NaN                NaN                             NaN
#
#   tags.image tags.opening_hours:cafe tags.currency:XBT tags.payment:lightning  \
# 0        NaN                     NaN               NaN                    NaN
# 1        NaN                     NaN               NaN                    NaN
# 2        NaN                     NaN               NaN                    NaN
# 3        NaN                     NaN               NaN                    NaN
# 4        NaN                     NaN               NaN                    NaN
#
#   tags.payment:lightning_contactless tags.payment:onchain tags.name:zh-Hans
# 0                                NaN                  NaN               NaN
# 1                                NaN                  NaN               NaN
# 2                                NaN                  NaN               NaN
# 3                                NaN                  NaN               NaN
# 4                                NaN                  NaN               NaN
#
# [5 rows x 267 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 7  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61af01ba632d85329fc4cbbfae17052c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61af01ba632d85329fc4cbbfae17052c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61af01ba632d85329fc4cbbfae17052c = L.map(
#                 &quot;map_61af01ba632d85329fc4cbbfae17052c&quot;,
#                 {
#                     center: [47.00728918135159, 7.996782838066722],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_61af01ba632d85329fc4cbbfae17052c);
#
#
#
#
#
#             var tile_layer_06c8c44539e3585b90bdcd6e37246b5c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_06c8c44539e3585b90bdcd6e37246b5c.addTo(map_61af01ba632d85329fc4cbbfae17052c);
#
#
#             var marker_3ce8a17d86ca0308b64c892fdf198d29 = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_61af01ba632d85329fc4cbbfae17052c);
#
#
#         var popup_9c6f9dbc6a7f2115ea8fd880cdcb5e97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_10c9878bac90b7cae089769b8e36fa82 = $(`&lt;div id=&quot;html_10c9878bac90b7cae089769b8e36fa82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_9c6f9dbc6a7f2115ea8fd880cdcb5e97.setContent(html_10c9878bac90b7cae089769b8e36fa82);
#
#
#
#         marker_3ce8a17d86ca0308b64c892fdf198d29.bindPopup(popup_9c6f9dbc6a7f2115ea8fd880cdcb5e97)
#         ;
#
#
#
#
#             var marker_e5955115d71df2c596b3ddf2b617186c = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_61af01ba632d85329fc4cbbfae17052c);
#
#
#         var popup_2f96d5f18589fd2e2d4c0fe292a254c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1d0076e234e36a7e3f0e1dab0bdc10b = $(`&lt;div id=&quot;html_c1d0076e234e36a7e3f0e1dab0bdc10b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_2f96d5f18589fd2e2d4c0fe292a254c6.setContent(html_c1d0076e234e36a7e3f0e1dab0bdc10b);
#
#
#
#         marker_e5955115d71df2c596b3ddf2b617186c.bindPopup(popup_2f96d5f18589fd2e2d4c0fe292a254c6)
#         ;
#
#
#
#
#             var marker_0e53d810e4a623533a9fb062df93947e = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_61af01ba632d85329fc4cbbfae17052c);
#
#
#         var popup_1ac18659f5a77f9f9e76b5646823cc00 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e79e587290143b8fba4c17a860050eb6 = $(`&lt;div id=&quot;html_e79e587290143b8fba4c17a860050eb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_1ac18659f5a77f9f9e76b5646823cc00.setContent(html_e79e587290143b8fba4c17a860050eb6);
#
#
#
#         marker_0e53d810e4a623533a9fb062df93947e.bindPopup(popup_1ac18659f5a77f9f9e76b5646823cc00)
#         ;
#
#
#
#
#             var marker_fb241d94ac85dd8ba143f1bb77376bfe = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_61af01ba632d85329fc4cbbfae17052c);
#
#
#         var popup_06bf5adff68e938c2f0d4f2e95af3d05 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1d189ae5e099ac260b5590583eafc32 = $(`&lt;div id=&quot;html_c1d189ae5e099ac260b5590583eafc32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_06bf5adff68e938c2f0d4f2e95af3d05.setContent(html_c1d189ae5e099ac260b5590583eafc32);
#
#
#
#         marker_fb241d94ac85dd8ba143f1bb77376bfe.bindPopup(popup_06bf5adff68e938c2f0d4f2e95af3d05)
#         ;
#
#
#
#
#             var marker_f1c97c58ab4048a0d89b3d0e1e93412a = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_61af01ba632d85329fc4cbbfae17052c);
#
#
#         var popup_25bf30e010e041927044908cc74faa9e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12694376b509ce461e978197f8ab2a09 = $(`&lt;div id=&quot;html_12694376b509ce461e978197f8ab2a09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_25bf30e010e041927044908cc74faa9e.setContent(html_12694376b509ce461e978197f8ab2a09);
#
#
#
#         marker_f1c97c58ab4048a0d89b3d0e1e93412a.bindPopup(popup_25bf30e010e041927044908cc74faa9e)
#         ;
#
#
#
#
#             var marker_c19d835e85da34c381397633e1336aab = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
